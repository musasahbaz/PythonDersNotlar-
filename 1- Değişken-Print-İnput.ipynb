# %% [markdown]
# ##  🪄 SAYILAR-METİNLER-DEĞİŞKENLER - print Fonksiyonu

# %%
a=10  #a isminde bir değişken tanımlandı ve değer olarak 10 atandı ✨
print(a)
# Out:
# 10

# %% [markdown]
# 👉 #### "#" işareti ile başlayan satırlar işleme konmaz. Çoğunlukla açıklama yapmak için kullanılır. O satırı pasif yapmak için de kullanılır. 🚫

# %%
# Bu bir yorum ve açıklama satırıdır.Ekranda çıktı olarak gözükmez ✨
print("Merhaba")
# Out:
# Merhaba

# %%
a = 20
b = a + 5     #a'nın 5 fazlasını b'ye atadı ✨
print(b)
# Out:
# 25

# %%
a= 10
b = 40 
c = a + b    # c değişkeni a ile b'nin toplamını değer olarak aldı ✨
print("SONUÇ = " , c)
# Out:
# SONUÇ =  50

# %%
x = 13
x = x + 1    #x'in değerini 1 arttır ✨
print ( x )
# Out:
# 14

# %%
x = 13
x += 1      #x=x+1 ile aynı işi yapar ✨
print(x)
# Out:
# 14

# %%
x = 50
x *= 2      #x'in değerini 2 katına çıkar ✨
print(x)
# Out:
# 100

# %%
x = 20
x /= 3      #x'in değerini 3'e böl ve yeni değer bu olsun ✨
print(x)
# Out:
# 6.666666666666667

# %% [markdown]
# #### 🔢 ÜS VE MOD

# %%
a = 12*12  # Çarpma işlemi ✨
print(a)
# Out:
# 144

# %%
a = 12**2 # Üs almak için ** kullanılır. ✨
print(f"{12} sayısının karesi = {a} dır")
# Out:
# 12 sayısının karesi = 144 dır

# %%
a = pow(12,2) # Üs almak için pow formülü de kullanılır. (Power kelimesinden gelir) ✨
print(f"{12} sayısının karesi = {a} dır") # pow() fonksiyonu da üs almak için kullanılabilir ✨
# Out:
# 12 sayısının karesi = 144 dır

# %% [markdown]
# ##### ✔️ KAREKÖK HESAPLAMA

# %%
a = 81**0.5     # 81**(1/2) ile aynı görevi yerine getirir.Karekökünü alır ✨

print(f"{81} sayısının kare kökü = {a} dır")
# Out:
# 81 sayısının kare kökü = 9.0 dır

# %%
print(pow(81,0.5))    #81 sayısının 2.dereceden kökünü alır ✨
# Out:
# 9.0

# %% [markdown]
# ##### ♟️ MOD HESAPLAMA (BÖLÜMÜNDEN KALANI BULMA)

# %%
print( 26 % 7 )  # 26 nın 7 ye bölümünden kalanı verir.Mod. ✨
# Out:
# 5

# %%
print(53 % 10)   # 53'ün 10'a bölümünden kalanını hesaplar ✨
# Out:
# 3

# %% [markdown]
# #### ✅ÇOKLU DEĞİŞKENE DEĞER ATAMA

# %%
x=y=50 #Aynı değeri çoklu değişkenlere atama ✨

print (x)
print (y)
# Out:
# 50
# 50

# %%
x,y,z = 5,7,9 #farklı değeri çoklu değişkenlere atama ✨

print (x)
print (y)
# Out:
# 5
# 7

# %%
ocak = mart = mayıs = temmuz = ağustos = ekim = aralık = 31    # ay isimleri 3 gruba bölünerek değerler verildi ✨
nisan = haziran = eylül = kasım = 30
şubat = 29

print(eylül)
# Out:
# 30

# %%
y1,y2,perf = 90,95,100  #tek satırda 3 değişken tanımlandı ve değerleri atandı.,, ✨

print (y1)
print (perf)

ort=(y1+y2+perf)/3

print (f"ORTALAMA ={ort}")
# Out:
# 90
# 100
# ORTALAMA =95.0

# %% [markdown]
# #### ❇️ DEĞİŞKEN TAKASI

# %%
almanya ="Paris"
fransa = "Berlin"    #Başkent eşleştirmesi yanlış ✨

almanya, fransa = fransa, almanya      #değişken değerleri yer değiştiriyor ✨
print("Almanya'nın Başkenti :", almanya)
print("Fransa'nın Başkenti :", fransa)
# Out:
# Almanya'nın Başkenti : Berlin
# Fransa'nın Başkenti : Paris

# %%
oyuncu="Yavuz Turgul"
yonetmen="Şener Şen"
oyuncu,yonetmen = yonetmen,oyuncu #değerleri yer değiş ✨

print( oyuncu )
# Out:
# Şener Şen

# %% [markdown]
# ####  ♟️TYPE FONKSİYONU()
# ###### type() fonksiyonu değişkenin veri tipini verir.

# %%
adi = "Ova"
a = 50
pi = 3.14
harf = "e"

print("adi değişkenininin türü =", type(adi)) 
print("a değişkenininin türü =", type(a))
print("pi değişkenininin türü =", type(pi))
print("harf değişkenininin türü =", type(harf))
# Out:
# adi değişkenininin türü = <class 'str'>
# a değişkenininin türü = <class 'int'>
# pi değişkenininin türü = <class 'float'>
# harf değişkenininin türü = <class 'str'>

# %% [markdown]
# #### ✅ LEN FONKSİYONU()
# ##### Değişkenin string karakter uzunluğunu verir. Sadece string değerlerde çalışır

# %%
a= len("Ankara")   # Ankara kelimesinin kaç karakterden oluştuğunu hesaplar ✨
print (a)
# Out:
# 6

# %%
sonuc="KALDI"
print( len (sonuc))
# Out:
# 5

# %%
print("Bilgisayar kelimesinin uzunluğu = ", len("Bilgisayar"))
# Out:
# Bilgisayar kelimesinin uzunluğu =  10

# %%
yer="Kuzguncuk" #String bir karakter dizisidir ✨
print(yer[3]) #Dizinin 3.elemanı ✨
print(yer[0])
# Out:
# g
# K

# %% [markdown]
# ##### ♟️ TİP DÖNÜŞTÜRME

# %%
print( int(3.14) ) # 3.14 float sayısını bir alt tamsayı yapar (aşağı yuvarlar). Yani ondalıklı kısmı tamamen siler.  ✨
# Out:
# 3

# %%
print( int(5.9) )
# Out:
# 5

# %%
print( str(36) ) # integer olan tam sayıyı stringe dönüştür.  ✨
# Out:
# 36

# %%
print( float(15) ) # Tam sayıyı, floata çevir ✨
# Out:
# 15.0

# %%
pi=3.14
print( int(pi) )
# Out:
# 3

# %% [markdown]
# #### ❇️ round () fonksiyonu ile sayı yuvarlama

# %%
print( round(2.3) ) #round() yuvarla fonksiyonudur. Sayının ondalıklı kısmına bakarak, sayıyı aşağı ya da yukarı yuvarlar ✨
# Out:
# 2

# %%
print( round(2.8)) #Ondalıklı kısım 5 veya 5'ten büyükse üst sayıya yuvarlar ✨
# Out:
# 3

# %%
print( round(2.4912))
# Out:
# 2

# %%
print( round(2.721)) #Ondalıklı kısmı 2 basamak yaz ✨
# Out:
# 3

# %% [markdown]
# ##### ✅ METİNLERLE ÇALIŞMA

# %%
adi="Kemal"                       #adi isminde bir değişken tanımlandı ve değer atandı ✨
soyadi="Sunal"
print( adi)
# Out:
# Kemal

# %%
adi="Kemal"                       #adi isminde bir değişken tanımlandı ve değer atandı ✨
soyadi="Sunal"
adiSoyadi = adi + soyadi         #adi ve soyadi değişkenleri birleştirildi ama boşluksuz ✨
print (adiSoyadi)
# Out:
# KemalSunal

# %%
adi="Kemal"                       #adi isminde bir değişken tanımlandı ve değer atandı ✨
soyadi="Sunal"
adiSoyadi=adi+" "+soyadi
print (adiSoyadi)
# Out:
# Kemal Sunal

# %%
adi="Kemal"                       #adi isminde bir değişken tanımlandı ve değer atandı ✨
soyadi="Sunal"
print(adi,soyadi)            # aralara boşluk ekleyerek yazar ✨
# Out:
# Kemal Sunal

# %%
print('Sabahattin', 'Ali') # Araya boşluk koyarak kelimeleri yazar ✨
# Out:
# Sabahattin Ali

# %%
 print('Peyami', 'Safa', 'İstanbul', 1899)
# Out:
# Peyami Safa İstanbul 1899

# %%
print("Ahmet" + " " + "Hamdi" + " " +  "TANPINAR")               #bu şekilde de metin birleştirme yapılabilir ✨
# Out:
# Ahmet Hamdi TANPINAR

# %%
print( "Oğuz"+"ATAY" )  #metni birleştirir, boşluk bırakmaz ✨
# Out:
# OğuzATAY

# %%
print ( 4+9 )
# Out:
# 13

# %%
print ( 4+"Oğuz" )   # Matematiksel işlemler sadece sayısal değerlerde yapılabilir. ✨
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 print ( 4+"Oğuz" )   # Matematiksel işlemler sadece sayısal değerlerde yapılabilir.
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print (45+"55")   # İnterger ile String toplanamaz ✨
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 print (45+"55")   # İnterger ile String toplanamaz
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print ( "45"+"55" )   # Tırnak içinde girilen değerler String olarak işlem görür ve birleştirilir. ✨
# Out:
# 4555

# %%
print ( "Metin"*5 )   # Belirtilen stringi 5 kere çoğaltır.  ✨
# Out:
# MetinMetinMetinMetinMetin

# %%
print ( "=" * 30 )     # eşittir işaretinden 30 tene çoğaltarak yazar ✨

# %% [markdown]
# ##### * oparetörünün metinlerle kullanımı

# %%
print(*"Çanakkale")   #stringin başına * operatörü konulursa o stringi karakterlere ayırır  ✨
# Out:
# Ç a n a k k a l e

# %%
print(*"Çanakkale")  #Karakterlere ayırır ve araya boşluk ekler ✨
# Out:
# Ç a n a k k a l e

# %%
print(*"Çanakkale",sep="-")   # sep parametresi ile herbir karakter arasına - işareti eklenebilir ✨
# Out:
# Ç-a-n-a-k-k-a-l-e

# %% [markdown]
# #### ♟️ Print Fonksiyonu ve Formatlama

# %% [markdown]
#  ##### "#" işareti ile başlayan satırlar işleme konmaz. Çoğunlukla açıklama yapmak için kullanılır

# %% [markdown]
# #Kodlarımızı dosyalara yazdığımızda, eğer ekrana bir değer bastırmak istersek *print* fonksiyonunu kullanırız.
# Kullanımı oldukça basittir ve değişik özelliklere sahiptir. Örneklerimize bakalım.

# %%
print('Merhaba Dünya') #Tek tırnak ile çift tırnak aynı işi görür ✨
# Out:
# Merhaba Dünya

# %%
print("Merhaba Dünya") #Bu örnek çift tırnak ile yazıldı ama aynı sonuç alınır.  ✨
# Out:
# Merhaba Dünya

# %%
print('''Merhaba Dünya''') # Üç tırnak da kullanılabilir :) Sonuç yine aynı olur. ✨
# Out:
# Merhaba Dünya

# %%
# 3 tırnak kullanımınn sağladığı ilk fayda, çoklu satır yazmak. Alt alta satırlar şeklinde çıktı alınabilir.  ✨

print(''' MENÜ
        ----------------------
        1 - PARA ÇEKME
        2-  PARA YATIRMA
        3-  BAKİYE GÖRÜNTÜLE
        4-  PARA AKTAR
        5-  ÇIKIŞ 
        ----------------------
        ''')
# Out:
#  MENÜ
#         ----------------------
#         1 - PARA ÇEKME
#         2-  PARA YATIRMA
#         3-  BAKİYE GÖRÜNTÜLE
#         4-  PARA AKTAR
#         5-  ÇIKIŞ
#         ----------------------

# %%
print("Python programlama dilinin adı "piton" yılanından gelmez") #Hata verir. Çift tırnak ile başlayan ve biten  cümle içinde çift tırnak kullanılmış. ✨
# Out:
#   Cell In[123], line 1
#     print("Python programlama dilinin adı "piton" yılanından gelmez") #Hata verir. Çift tırnak ile başlayan ve biten  cümle içinde çift tırnak kullanılmış.
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
# Bu hatayı şu şekilde çözebiliriz ✨

# %%
print('Python programlama dilinin adı "piton" yılanından gelmez') # Tek tırnak ile başlayarak ✨
# Out:
# Python programlama dilinin adı "piton" yılanından gelmez

# %%
print('İstanbul'un 5 günlük hava durumu tahmini') # Hata verir. Tek tırnak ile başlayıp biten cümle içinde tek tırnak kullanılmış. ✨
# Out:
#   Cell In[125], line 1
#     print('İstanbul'un 5 günlük hava durumu tahmini') # Hata verir. Tek tırnak ile başlayıp biten cümle içinde tek tırnak kullanılmış.
#                                                    ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
#ÇÖZÜM:
 print("İstanbul'un 5 günlük hava durumu tahmini")
# Out:
#   Cell In[64], line 2
#     print("İstanbul'un 5 günlük hava durumu tahmini")
#     ^
# IndentationError: unexpected indent

# %%
 # Aşağıdaki örnekte Hem tek tırnak, hem de çift tırnak kullanılmış ✨

# %%
print("O an Atatürk'ün "Ne mutlu Türküm diyene" sözü gelir")
# Out:
#   Cell In[66], line 1
#     print("O an Atatürk'ün "Ne mutlu Türküm diyene" sözü gelir")
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# ### ❇️ \ (ters taksim) kaçış operatörü

# %%
\ operatörü ile kendinden sonra komut görevi olan karakterin o görevi iptal edilir. Tek karakter için geçerlidir. ✨

# %%
print('Yarın Adana'ya gidiyorum.') #Hata. Burada Adana'ya yazan yerdeki tek tırnak cümleyi bitiriyor ve hataya sebep oluyor.
# Out:
#   Cell In[67], line 1
#     print('Yarın Adana'ya gidiyorum.') #Hata
#                                     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('Yarın Adana\'ya gidiyorum.') #Hata giderildi. Adana'ya yazan yerdeki tek tırnağın cümleyi bitirme görevi iptal edildi.  ✨
# Out:
# Yarın Adana'ya gidiyorum.

# %%
print(" "book" kelimesi Türkçede "kitap" anlamına gelir.") #Hatalı
# Out:
#   Cell In[69], line 1
#     print(" "book" kelimesi Türkçede "kitap" anlamına gelir.") #Hatalı
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
print("\"book\" kelimesi Türkçede \"kitap\" anlamına gelir.")
# Out:
# "book" kelimesi Türkçede "kitap" anlamına gelir.

# %%
#ya da daha kolayı şu: üç tırnak kullanımı ✨

print("""Python programlama dilinin adı "piton" yılanından gelmez""") #doğru kullanım ✨
# Out:
# Python programlama dilinin adı "piton" yılanından gelmez

# %%
print("""İstanbul'un 5 günlük hava durumu tahmini""") #doğru kullanım ✨
# Out:
# İstanbul'un 5 günlük hava durumu tahmini

# %%
print(''' O an Atatürk'ün "Ne mutlu Türküm diyene" sözü gelir ''')
# Out:
#  O an Atatürk'ün "Ne mutlu Türküm diyene" sözü gelir

# %% [markdown]
# #### ✳️ sep parametresi kullanımı

# %%
print("http://", "www.", "istihza.", "com") # Araya boşluk koyar ✨
# Out:
# http:// www. istihza. com

# %%
print("http://", "www.", "istihza.", "com",sep="") #sep parametresi ile boşluklar kalkıyor ✨
# Out:
# http://www.istihza.com

# %%
print("www","okul","meb","k12","tr",sep="-")
# Out:
# www-okul-meb-k12-tr

# %%
print("www","okul","meb","k12","tr",sep=".") #sep ile aralara nokta işareti koyalım ✨
# Out:
# www.okul.meb.k12.tr

# %%
print(1,2,3,4,5,6,sep=" para ")
# Out:
# 1 para 2 para 3 para 4 para 5 para 6

# %%
#6' dan sonra da para yazması için end parametresi kullanılmalı. end sadece en sona ekleme yapar ✨

# %% [markdown]
# #### ♟️ end parametresi

# %%
print(1,2,3,4,5,6, end=" para") #sadece en sona ekleme yapar ✨
# Out:
# 1 2 3 4 5 6 para

# %%
print(1,2,3,4,5,6,sep=" para ", end=" para")
# Out:
# 1 para 2 para 3 para 4 para 5 para 6 para

# %% [markdown]
# #### ✳️ \n ile yeni satır oluşturma (new line)

# %%
print("Taş Kağıt Makas")     #tek satırda yazar ✨
# Out:
# Taş Kağıt Makas

# %%
print("Taş \nKağıt \nMakas")     #Çoklu satırda yazar ✨
# Out:
# Taş
# Kağıt
# Makas

# %%
print("birinci satır ikinci satır üçüncü satır")
# Out:
# birinci satır ikinci satır üçüncü satır

# %%
print("birinci satır \nikinci satır \nüçüncü satır")
# Out:
# birinci satır
# ikinci satır
# üçüncü satır

# %% [markdown]
# #### ✅ \t sekme oluşturma

# %%
print("abc\tdef")
# Out:
# abc	def

# %%
print("bir", "iki", "üç", sep="\t")
# Out:
# bir	iki	üç

# %%
print("""
        ADI: Ali
        SOYADI: GÜN
        TEL: 533 222 11 00
        """)
# Out:
#         ADI: Ali
#         SOYADI: GÜN
#         TEL: 533 222 11 00

# %%
print("""
        ADI\t\t: Ali
        SOYADI\t\t: GÜN
        TEL\t\t: 533 222 11 00
        """)
# Out:
#         ADI		: Ali
#         SOYADI		: GÜN
#         TEL		: 533 222 11 00

# %% [markdown]
# #### 🎯 print Formatlama

# %% [markdown]
# Programlama yaparken bazı yerlerde bir stringin içinde daha önceden tanımlı string,float, int vs. değerleri yerleştirmek isteyebiliriz.
# Böyle durumlar için Pythonda *format()* fonksiyonu bulunmaktadır.
# Örneğin, programımızda 3 tane tamsayı değerimiz var ve biz bunları bir string içinde ekrana basmak istiyoruz.
# Bunun için *format()* fonksiyonunu kullanabiliriz.
# *format()* fonksiyonunun çok fazla özelliği olduğu için, ben burada sadece en çok kullandığımız özelliğini göstereceğim. {} parantezleri ile veri alanları oluşturularak bu alanlara istenen değerler ya da değişkenler aktarılabilir.

# %%
print("Merhaba {}".format("Ali"))
# Out:
# Merhaba Ali

# %%
# Burada 3 tane süslü parantezimiz ({}) var ve bunların yerine sırasıyla format fonksiyonun içindeki değerler geçiyor. ✨
print("{} {} {}".format(1,2,3))
# Out:
# 1 2 3

# %%
ad = "Ali"
print("Merhaba {}, nasılsın?".format(ad))
# Out:
# Merhaba Ali, nasılsın?

# %%
a = 3
b = 4
print("{} + {} 'nin toplamı {} 'dır".format(a,b,a+b))
# Out:
# 3 + 4 'nin toplamı 7 'dır

# %%
# Süslü parantezlerin içindeki sayılar format fonksiyonun içinden hangi sıradaki değerin geleceğini söylüyor. ✨
"{1} {0} {2}".format(43,"Murat",54)
# Out:
# 'Murat 43 54'

# %%
# Süslü parantezlerin içindeki kullanım ondalıklı kısmın sadece 2 basamağına kadar almak istediğimiz söylüyor. ✨
"{:.2f} {:.2f} {:.3f}".format(3.1463,5.324,7.324324)
# Out:
# '3.15 5.32 7.324'

# %% [markdown]
# #### ✳️ f parametre kullanımı

# %% [markdown]
# .format kullanımına göre daha pratik bir yapısı vardır. print fonksiyonun hemen başına yazılır. { } parantezleri ile oluşturulan veri alanlarına istenen değişken veya değerler yazılırarak kullanılabilir.

# %%
ad = 'Ali'
soyad = 'ER'
burc = "YAY"

print(f'Selam {ad} {soyad} . Sen {burc} özelliklerini taşıyorsun.')
# Out:
# Selam Ali ER . Sen YAY özelliklerini taşıyorsun.

# %%
isim = 'Ali'
yas = 18
print(f'Onun adı {isim} ve o {yas} yaşında.')
# Out:
# Onun adı Ali ve o 18 yaşında.

# %%
# Aynı örneği format() fonksiyonu ile de yazıp arasındaki farka bakalım: ✨

# %%
isim = 'Ali'
yas = 18
print("Onun adı {} ve o {} yaşında.".format(isim, yas))
# Out:
# Onun adı Ali ve o 18 yaşında.

# %% [markdown]
# ### ♾️ MANTIKSAL VERİ TÜRLERİ

# %% [raw]
# <  : Küçük mü
# >  : Büyük mü
# >= : Büyük eşit mi
# <= : Küçük eşit mi
# == : Eşit mi
# =! : Farklı mı

# %%
3<10
# Out:
# True

# %%
pi = 3.14

# %%
5 > pi
# Out:
# True

# %%
# ==	eşit mi ? ✨
pi == 3.14
# Out:
# True

# %%
pi != 5 # != Eşit değil (Farklı mı?) ✨
# Out:
# True

# %%
5 == 4
# Out:
# False

# %%
x = 5 
y = 5

x == y
# Out:
# True

# %%
#  !=	eşit değil mi?	(Farklı mı? ) ✨
10 != 9
# Out:
# True

# %%
5 != 5
# Out:
# False

# %%
# >	Büyük mü ?	
5 > 5
# Out:
# False

# %%
7 > 2
# Out:
# True

# %%
# <	Küçük mü ? ✨
8 < 5
# Out:
# False

# %%
8 < 9
# Out:
# True

# %%
#  >=	Büyük eşit mi ?	 ✨

# %%
5 >= 5
# Out:
# True

# %%
5 >= 8
# Out:
# False

# %%
#   <=	Küçük eşit mi ?	 ✨

# %%
5 <= 5
# Out:
# True

# %%
5 <= 3
# Out:
# False

# %% [markdown]
# ### ✳️ input () komutu ile kullanicıdan veri alma

# %% [raw]
# input() fonksiyonu ile kullanıcının klavyeden veri girişi yapmasını sağlarız. Girilen veriler değişkenlere aktarılarak kullanılabilir.

# %%
isim = input("İsminiz nedir : ")         #isim değişkenine, input ile klavyeden girilen değerler atanıyor ✨
print("Merhaba",isim, "nasılsın?")       #print komutunda metinler ile değişkenler arasına virgül konulur. ✨
# Out:
# İsminiz nedir :  Ece
# Merhaba Ece nasılsın?

# %% [markdown]
# ##### ❗ DİKKAT: input() komutu ile alınan veriler daima string yapıya sahiptir.

# %%
sayil = input("1. Sayıyı Giriniz : ")
sayi2 = input("2.Sayıyı Giriniz: ")
hesapla = sayil + sayi2
print("Girilen sayıların toplamı =", hesapla)
# Out:
# 1. Sayıyı Giriniz :  12
# 2.Sayıyı Giriniz:  78
# Girilen sayıların toplamı = 1278

# %% [markdown]
# ##### ❗ Girilen değerler string olarak alındığı için + işlemi ile bu iki string birleştirildi.

# %% [markdown]
# ##### 💢 Bu hatayı düzeltmek için bir kaç yöntem mevcuttur. Öncelikle string olarak alınan değerlerin integer'a dönüştürülmesi gerekiyor

# %%
sayil = input("1.Sayıyı Giriniz: ")
sayi2 = input("2.Sayıyı Giriniz: ")
hesapla = int(sayil) + int(sayi2) #sayil ve sayi2 integer'a dönüştürülür. ✨
print("Girilen sayıların toplamı =", hesapla)
# Out:
# 1.Sayıyı Giriniz:  12
# 2.Sayıyı Giriniz:  78
# Girilen sayıların toplamı = 90

# %% [markdown]
# ##### 💢 Yukarıdaki işlemde sayılar geçici olarak integer'a dönüştürüldü.
# Ya da integer'a dönüşüm işlemi sayı kullanıcıdan alınırken yapılır ve bu şekilde programın bundan sonraki her yerinde sayı olarak kullanılabilirler.

# %%
sayil = int(input("1.Sayıyı Giriniz : "))   # input ile alınan değer değişkene sayı olarak aktarıldı. ✨
sayi2 = int(input("2.Sayıyı Giriniz: "))
hesapla = sayil + sayi2
#int() fonksiyonu ile input edilen string, integer'a dönüştürülür
print("Girilen sayıların toplamı =", hesapla)
# Out:
# 1.Sayıyı Giriniz :  12
# 2.Sayıyı Giriniz:  78
# Girilen sayıların toplamı = 90

# %%
Kullanıcıdan alınan iki adet sayıyı kullanarak bir kaç işlem yaptıralım

# %%
sayi1 = int(input("1.Sayıyı Giriniz : "))  #sayi1 artık bir integer
sayi2 = int(input("2.Sayıyı Giriniz: "))    #sayi2 de integer

print("TOPLAM \t=", sayi1 + sayi2)
print("FARK \t=", sayi1 - sayi2)
print("ÇARPIM \t=", sayi1 * sayi2)
print("BÖLÜM \t=", sayi1 / sayi2)
# Out:
# 1.Sayıyı Giriniz :  12
# 2.Sayıyı Giriniz:  3
# TOPLAM 	= 15
# FARK 	= 9
# ÇARPIM 	= 36
# BÖLÜM 	= 4.0

# %% [markdown]
# ####  🛠️ Sen yap:
# Kullanıcıdan bir sayı girilmesini iste, daha sonra kullanıcının girdiği bu sayının karesini ekrana yazdıran kodu yaz.

# %%
a = int(input("Sayı giriniz : "))
print(f"Girilen sayının karesi = { a*a } 'dır")
# Out:
# Sayı giriniz :  7
# Girilen sayının karesi = 49 'dır

# %% [markdown]
# ##### 💢 Kullanıcıdan çoklu değer almak

# %%
#yazılı notlarının alınmasını tek satırda yapmak için ✨
y1, y2, y3 = int(input("1.YAZILI : ")),int(input("2.YAZILI : ")), int(input("3.YAZILI : "))
ort = (y1+y2+y3)/3
print("ORTALAMANIZ= ",ort)
# Out:
# 1.YAZILI :  80
# 2.YAZILI :  90
# 3.YAZILI :  100
# ORTALAMANIZ=  90.0

# %% [markdown]
# #### ÖRNEKLER

# %% [markdown]
# ##### 1️⃣: Girilen kişi bilgilerini yazdırma

# %%
print("Lütfen aşağıdaki bilgileri giriniz")

x = input("Adınız \t: ")
y = input ("Soyadınız \t: ")
z = int(input("Yaşınız \t:"))
print("Bilgiler kaydedildi....")

print(f"Öğrencimiz {x} {y} şuan {z} yaşındadır.")
# Out:
# Lütfen aşağıdaki bilgileri giriniz
# Adınız 	:  Ova
# Soyadınız 	:  KALE
# Yaşınız 	: 15
# Bilgiler kaydedildi....
# Öğrencimiz Ova KALE şuan 15 yaşındadır.

# %% [markdown]
# ##### 2️⃣: Girilen 3 sayıyı toplayan program

# %%
a = int(input("1.Sayı giriniz : "))  # girilen değer integer'a dönüştürülür. ✨
b = int(input("2.Sayı giriniz : "))
c = int(input("3.Sayı giriniz : "))

hesapla = a + b + c
print(f"Girilen sayıların toplamı {hesapla}'dır")
# Out:
# 1.Sayı giriniz :  5
# 2.Sayı giriniz :  8
# 3.Sayı giriniz :  9
# Girilen sayıların toplamı 22'dır

# %% [markdown]
# #### SEN YAP ✨
# 🔴 1- Kullanıcıdan dikdörtgenin kenar uzunluklarını girilmesini iste, girilen uzunluklara göre dikdörtgenin alanını ve
# çevresini hesaplayıp ekrana yazdır.

# %%
u = int(input("Uzun kenarı giriniz : "))
k = int(input("Kısa kenarı giriniz : "))
alan = u * k
cevre = 2*u + 2*k

print(f"ALAN = {alan}")
print(f"ÇEVRE = {cevre}")
# Out:
# Uzun kenarı giriniz :  6
# Kısa kenarı giriniz :  2
# ALAN = 12
# ÇEVRE = 16

# %% [markdown]
# ##### 🟠 2- Kullanıcıdan doğum yılının girilmesini iste ve o kişinin yaşını hesaplayıp ekrana yazdır.

# %%
sene = int(input("Doğum yılınızı giriniz : "))
yas = 2025 - sene
print(f"Merhaba, doğum yılınız {sene} ve yaşınız {yas}'dır!")
# Out:
# Doğum yılınızı giriniz :  2000
# Merhaba, doğum yılınız 2000 ve yaşınız 25'dır!

# %% [markdown]
# ##### 🟡 3- Kullanıcıdan bir sayı girilmesini iste ve girilen bu sayının karekökünü, karesini ve küpünü hesaplayıp ekrana yazdır.

# %%
sayi = int(input("Sayıyı giriniz"))
kare = pow(sayi,2)
kup = pow(sayi,3)
karekok = pow(sayi, 0.5)

print(f"Girilen sayının karesi : { kare } ")
print(f"Girilen sayının küpü : { kup } ")
print(f"Girilen sayının karekökü : { karekok } ")
# Out:
# Sayıyı giriniz 9
# Girilen sayının karesi : 81
# Girilen sayının küpü : 729
# Girilen sayının karekökü : 3.0
