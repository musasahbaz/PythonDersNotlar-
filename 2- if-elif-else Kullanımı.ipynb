# %% [markdown]
# ### 🟥 if Kullanımı

# %% [markdown]
# Belirtilen şartın doğru olması durumunda çalışmasını istediğimiz kodlar if bloğunun içine yazılır.

# %% [markdown]
# if şart :
#     Şart doğru ise yapılacaklar
#
# ##### if yazdıktan sonra şartımızı yazarız ve sonrasına : konulur. ✨
# ##### if şartının doğru olması durumunda yapılmasını istediklerimizi bir tab içerden başlayarak yazmalıyız.✨

# %%
a = 5
b = 10

if a > b :
    print("a sayısı b sayısından büyüktür")
if b > a :
    print("b sayısı a sayısından büyüktür")
# Out:
# b sayısı a sayısından büyüktür

# %%
#Program çalıştığında kullanıcıdan bir sayı istesin ve bu sayının pozitif-negatif durumunu değerlendirsin    ✨

sayi = int(input("Bir sayı giriniz : "))    # Kullanıcıdan sayıyı input komutu ile alıyoruz   ✨   
if sayi > 0 :                               # Eğer sayı 0'dan büyükse ekrana "Pozitif" yazsın   ✨
    print("Girilen sayı pozitiftir.")
if sayi < 0 : 
    print("Girilen sayı negatiftir")
if sayi == 0 : 
    print("Girilen sayı sıfırdır.")
# Out:
# Bir sayı giriniz :  65
# Girilen sayı pozitiftir.

# %%
# Kullanıcıdan parola girilmesi istensin. Eğer girilen parola 1234 ise ekrana "Sisteme Hoşgeldiniz" yazsın   ✨

parola = input("Parola: ")
if parola == "1234":
    print("Sisteme Hoşgeldiniz!")
# Out:
# Parola:  1234
# Sisteme Hoşgeldiniz!

# %%
sicaklik = int(input("Hava sıcaklığını giriniz :" ))
if sicaklik > 25:
    print("Hava sıcak")
# Out:
# Hava sıcaklığını giriniz : 30
# Hava sıcak

# %% [markdown]
# #Klavyeden öğrenci puanı girilecek ve bu puanın not olarak kaça denk geldiği bulunacak.   ✨
#
# puan = int(input("Ders puanını giriniz: "))
#
# if puan < 50:
#     print("Notunuz: 1")
#
# if puan < 60:
#     print("Notunuz: 2")
#
# if puan < 70:
#    print("Notunuz: 3")
#
# if puan < 85:
#    print("Notunuz: 4")
#
# if puan <= 100:
#     print("Notunuz: 5")
#
# if puan > 100:
#     print("Hatalı giriş!")
#
# if puan < 0:
#     print("Hatalı giriş!")

# %% [markdown]
# ##### 🧩 Yukarıdaki örnekte görüldüğü gibi bir hata oluştu. Bu hatayı gidermek için elif kullanımını öğrenelim

# %% [markdown]
# ### 🟧 elif Kullanımı

# %%
elif , else if  deyiminin kısaltılmış halidir.

if şart :          #eğer bu şart doğru ise   ✨   
    yapılacaklar
elif şart 2 :      # eğer üstteki şart doğru değil de bu şart doğru ise   ✨
    yapılacaklar
elif şart 3 :      # eğer üstteki şart doğru değil de bu şart doğru ise   ✨
    yapılacaklar
elif şart 4 :      # eğer üstteki şart doğru değil de bu şart doğru ise   ✨
    yapılacaklar

Bu dört seçenekten sadece birisi çalıştırılır ve if bloğu bitirilir.

# %%
#Klavyeden öğrenci puanı girilecek ve bu puanın not olarak kaça denk geldiği bulunacak.   ✨

puan = int(input("Ders puanını giriniz: "))

if puan < 50:
    print("Notunuz: 1")

elif puan < 60:
    print("Notunuz: 2")

elif puan < 70:
   print("Notunuz: 3")

elif puan < 85:
   print("Notunuz: 4")

elif puan <= 100:
    print("Notunuz: 5")

elif puan > 100:
    print("Hatalı giriş!")

elif puan < 0:
    print("Hatalı giriş!")
# Out:
# Ders puanını giriniz:  55
# Notunuz: 2

# %% [markdown]
# ### 🟨 else Kullanımı

# %% [markdown]
# ###### 🧩 Klavyeden girilen öğrencinin notu 50 ve üstünde ise "GEÇTİ"; 50'nin altında ise "KALDI" yazsın   ✨

# %%
puan = int(input("Ders puanını giriniz: "))

if puan > 50:            # Girilen not 50 ve üstünde ise   ✨
    print("GEÇTİNİZ")
else :                   # Girilen not 50 ve üstünde değilse   ✨
    print("KALDINIZ")
# Out:
# Ders puanını giriniz:  65
# GEÇTİNİZ

# %% [markdown]
# 🧩 else, yukarıdaki şart doğru değilse şunu yap anlamında kullanılır. else'den sonra : konulur ve else durumunda çalışmasını istediğimiz satırlar bir tab içerden başlar

# %%
# Kullanıcıdan parola girilmesi istensin. Eğer girilen parola 1234 ise ekrana "Sisteme Hoşgeldiniz" yazsın.   ✨
# Girilen parola 1234 dışında ise ekrana "Yanlış parola!" yazsın   ✨

parola = input("Parola: ")
if parola == "1234":
    print("Sisteme Hoşgeldiniz!")
else :
    print("Yanlış parola!")
# Out:
# Parola:  abc123
# Yanlış parola!

# %% [markdown]
# #### 🟩 if - elif - else kullanımına dair örnekler

# %%
#ÖRNEK - 1 : Klavyeden girilen yaşa göre değerlendirme    ✨

yas = int(input("Yaşınızı giriniz : "))
if yas < 13:
    print("Çocuk")
elif yas < 18:
    print("Genç")
else:
    print("Yetişkin")
# Out:
# Yaşınızı giriniz :  17
# Genç

# %%
#ÖRNEK - 2 : Klavyeden girilen sıcaklık değerine göre değerlendirme   ✨

sicaklik =  int(input("Sıcaklık değeriniz giriniz : "))
if sicaklik < 10:
    print("Soğuk")
elif sicaklik < 25:
    print("Ilık")
else:
    print("Sıcak")
# Out:
# Sıcaklık değeriniz giriniz :  28
# Sıcak

# %%
#ÖRNEK - 3 : Klavyeden girilen sıcaklık değerine göre suyun halini bulma   ✨

sicaklik =  int(input("Suyun sıcaklık değeriniz giriniz : "))
if sicaklik < 0:
    print("KATI (Buz) ")
elif sicaklik < 100:
    print("SIVI")
else:
    print("GAZ")
# Out:
# Suyun sıcaklık değeriniz giriniz :  -10
# KATI (Buz)

# %%
#ÖRNEK - 4 : Klavyeden girilen sayının pozitif-neagatif durumu   ✨

sayi =  int(input("Sayı giriniz : "))
if sayi > 0:
    print("Pozitif")
elif sayi < 0:
    print("Negatif")
else:
    print("Sıfır")
# Out:
# Sayı giriniz :  45
# Pozitif

# %%
#ÖRNEK - 5 : Klavyeden girilen boy değerine göre değerlendirme   ✨

boy =  int(input("Boyunuzu cm olarak giriniz : "))
if boy < 150:
    print("Kısa")
elif boy < 180:
    print("Orta")
else:
    print("Uzun")
# Out:
# Boyunuzu cm olarak giriniz :  180
# Uzun

# %%
#ÖRNEK - 6 : Klavyeden girilen mesajın uzunluğuna göre değerlendirme   ✨

mesaj =  input("Mesajınızı giriniz : ")
if len(mesaj) < 5:
    print("Kısa mesaj")
elif len(mesaj) < 15:
    print("Orta mesaj")
else:
    print("Uzun mesaj")
# Out:
# Mesajınızı giriniz :  Hoş geldiniz
# Orta mesaj

# %%
#ÖRNEK - 7 : Klavyeden girilen  şifrenin uzunluğuna göre değerlendirme   ✨

sifre =  input("Şifrenizi giriniz : ")
if len(sifre) < 4:
    print("Zayıf şifre")
elif len(sifre) < 8:
    print("Orta şifre")
else:
    print("Güçlü şifre")
# Out:
# Şifrenizi giriniz :  123456
# Orta şifre

# %%
#ÖRNEK - 8 : Klavyeden girilen yaş değerine göre değerlendirme   ✨

yas =  int(input("Yaşınızı giriniz : "))
if yas < 7:
    print("Ücretsiz")
elif yas < 25:
    print("Öğrenci")
elif yas < 60:
    print("Tam")
else:
    print("65 yaş indirimli")
# Out:
# Yaşınızı giriniz :  40
# Tam

# %%
#ÖRNEK - 9 : Klavyeden girilen stok adedine göre değerlendirme   ✨

stok =  int(input("Stok adetini giriniz : "))
if stok == 0:
    print("Stok yok")
elif stok <= 10:
    print("Az stok")
else:
    print("Stok yeterli")
# Out:
# Stok adetini giriniz :  5
# Az stok

# %%
#ÖRNEK - 10 : Klavyeden girilen kargo kilo değerine göre değerlendirme   ✨

kilo =  int(input(" Kilonuzu giriniz : "))
if kilo < 1:
    print("Hafif paket")
elif kilo < 5:
    print("Orta paket")
else:
    print("Ağır paket")
# Out:
#  Kilonuzu giriniz :  8
# Ağır paket

# %%
#ÖRNEK - 11 : Klavyeden girilen sayı değerine göre değerlendirme   ✨

sayi =  int(input("Sayı giriniz : "))
if sayi % 2 == 1:
    print("Tek")
elif sayi % 2 == 0:
    print("Çift")
# Out:
# Sayı giriniz :  5
# Tek

# %%
#ÖRNEK - 12 : Klavyeden girilen ücrete göre değerlendirme   ✨

ucret =  int(input("Ücreti  giriniz : "))
if ucret < 30000:
    print("Düşük gelir")
elif ucret < 70000:
    print("Orta gelir")
else:
    print("Yüksek gelir")
# Out:
# Ücreti  giriniz :  7500
# Düşük gelir

# %% [markdown]
# #### 🟦 if kullanımının kısaltılmış hali

# %%
a = 15
b = 8

if a > b: print("a, b'den büyüktür")
# Out:
# a, b'den büyüktür

# %%
a = 2
b = 5
print("A") if a > b else print("B")
# Out:
# B
