# %% [markdown]
# # While Döngüsü
# ## 1️⃣ While Döngüsü Nedir?
# While döngüsü, belirli bir koşul doğru (True) olduğu sürece çalışan bir döngüdür.

# %% [markdown]
# 👉 Koşul doğru → Kod çalışır
# 👉 Koşul yanlış → Döngü durur

# %% [markdown]
# ### 2️⃣ While Döngüsünün Yapısı (Söz Dizimi)

# %%
while koşul:
    çalışacak_kodlar

# %% [markdown]
# ⚠️ Önemli:
#
# : işareti unutulmamalıdır.
#
# İçerideki kodlar girintili (indent) yazılmalıdır.
#
# Koşulun bir noktada False olması gerekir, yoksa döngü sonsuza kadar çalışır!

# %% [markdown]
# ##### 3️⃣ En Basit Örnek

# %%
# Örnek 1
sayi = 1
while sayi <= 5:
    print(sayi)
    sayi += 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ### Açıklama:
# Sayı 1'den başlar, 5'e kadar yazdırılır. 6 olduğunda döngü sona erer.
#
# Başlangıçta sayi = 1
#
# Koşul: sayi <= 5
#
# Her turda sayı 1 artıyor.
#
# 6 olduğunda koşul False olur ve döngü biter.

# %% [markdown]
# ### Açıklama:
# Sayı 1'den başlar, 5'e kadar yazdırılır. 6 olduğunda döngü sona erer.
#
# Başlangıçta sayi = 1
#
# Koşul: sayi <= 5
#
# Her turda sayı 1 artıyor.
#
# 6 olduğunda koşul False olur ve döngü biter.

# %% [markdown]
# #### 4️⃣ Sayaç Mantığını Anlamak
#
# While döngülerinde genellikle bir sayaç değişkeni kullanılır.

# %%
i = 0

while i < 3:
    print("Merhaba")
    i += 1
# Out:
# Merhaba
# Merhaba
# Merhaba

# %% [markdown]
# ##### 🔎 Burada:
#
# i 0’dan başlar.
#
# 3’e kadar çalışır.
#
# Toplam 3 kez "Merhaba" yazdırır.

# %% [markdown]
# #### ⚠️ EN ÖNEMLİ KONU: Sonsuz Döngü (Infinite Loop)
#
# Eğer sayaç artırılmazsa: (Kodu çalıştırmayın)

# %%
i = 1

while i <= 5:
    print(i)

# %% [markdown]
# ##### 🚨 Bu kod asla bitmez!
# Çünkü i hiç değişmiyor. Koşul hep True kalıyor.
#
# 👉 Bu duruma sonsuz döngü denir.

# %% [markdown]
# #### 5️⃣ Kullanıcıdan Veri Alma Örneği

# %%
sayi = int(input("Bir sayı girin (0 çıkış): "))

while sayi != 0:
    print("Girdiğiniz sayı:", sayi)
    sayi = int(input("Bir sayı girin (0 çıkış): "))
# Out:
# Bir sayı girin (0 çıkış):  5
# Girdiğiniz sayı: 5
# Bir sayı girin (0 çıkış):  6
# Girdiğiniz sayı: 6
# Bir sayı girin (0 çıkış):  0

# %% [markdown]
# ##### 🔎 Açıklama:
#
# Kullanıcı 0 girene kadar program çalışır.  0 girildiğinde döngü durur.
#
# 👉 Bu tür döngülere kontrollü döngü denir.

# %% [markdown]
# #### 6️⃣ Toplama İşlemi Örneği
#
# 1’den 100’e kadar sayıları toplayalım:

# %%
toplam = 0
sayi = 1

while sayi <= 100:
    toplam += sayi
    sayi += 1

print("Toplam:", toplam)
# Out:
# Toplam: 5050

# %% [markdown]
# ##### 🔎 Mantık:
#
# Her turda sayı toplama eklenir.
#
# Sayaç artar.
#
# 101 olduğunda döngü biter. toplam değişkeninde ise sayaçın aldığı değer toplanır her adımda

# %% [markdown]
# #### 7️⃣ Şifre Kontrol Örneği

# %%
sifre = "1234"
giris = input("Şifre giriniz: ")

while giris != sifre:
    print("Hatalı şifre!")
    giris = input("Tekrar deneyin: ")

print("Giriş başarılı.")
# Out:
# Şifre giriniz:  abcd
# Hatalı şifre!
# Tekrar deneyin:  1234
# Giriş başarılı.

# %%
sifre = "1234"
giris = input("Şifre giriniz: ")

while giris != sifre:
    print("Hatalı şifre!")
    giris = input("Tekrar deneyin: ")

print("Giriş başarılı.")
# Out:
# Şifre giriniz:  abcd
# Hatalı şifre!
# Tekrar deneyin:  1234
# Giriş başarılı.

# %% [markdown]
# ##### 👉 Doğru şifre girilene kadar sistem çalışır.

# %% [markdown]
# #### 8️⃣ break Komutu
#
# break döngüyü zorla bitirir.

# %%
while True:
    sayi = int(input("Bir sayı girin (negatif çıkış): "))
    
    if sayi < 0:
        break
    
    print("Girdiğiniz sayı:", sayi)

print("Negatif sayı girdiğiniz için döngü bitti...")
# Out:
# Bir sayı girin (negatif çıkış):  5
# Girdiğiniz sayı: 5
# Bir sayı girin (negatif çıkış):  78
# Girdiğiniz sayı: 78
# Bir sayı girin (negatif çıkış):  12
# Girdiğiniz sayı: 12
# Bir sayı girin (negatif çıkış):  -3
# Negatif sayı girdiğiniz için döngü bitti...

# %% [markdown]
# ##### 🔎 Burada:
#
# while True sonsuz döngüdür.
#
# Ama negatif girilirse break ile durur.

# %% [markdown]
# #### 9️⃣ continue Komutu
#
# continue bulunduğu turu atlar, başa döner.

# %%
sayi = 0

while sayi < 5:
    sayi += 1
    
    if sayi == 3:
        continue
    
    print(sayi)
# Out:
# 1
# 2
# 4
# 5

# %% [markdown]
# ##### 🔎 3 yazdırılmaz çünkü o tur atlanır.

# %% [markdown]
# #### 1️⃣0️⃣ While - else Kullanımı
#
# Python’da döngü normal şekilde biterse else çalışır.

# %%
sayi = 1

while sayi <= 3:
    print(sayi)
    sayi += 1
else:
    print("Döngü bitti.")
# Out:
# 1
# 2
# 3
# Döngü bitti.

# %% [markdown]
# #### 🎯 While Döngüsünde Dikkat Edilmesi Gerekenler
#
# ✅ Koşul mutlaka değişmeli
#
# ✅ Sayaç artırılmalı veya azaltılmalı
#
# ✅ Sonsuz döngü riski kontrol edilmeli
#
# ✅ Girintiye dikkat edilmeli
#
# ✅ break ve continue bilinçli kullanılmalı

# %% [markdown]
# #### 🎯 Sayı Tahmin Oyunu (While Döngüsü ile)

# %% [markdown]
# Bilgisayar 1-100 arası rastgele bir sayı tutar ve kullanıcıdan bu sayıyı tahmin etmesi istenir. Kullanıcının 10 tahmin hakkı vardır. Her tahminde kullanıcıya ipucu verilir.

# %%
import random

# Bilgisayar 1 ile 100 arasında rastgele sayı tutuyor
tutulan_sayi = random.randint(1, 100)

tahmin_hakki = 10
sayac = 0

print("1 ile 100 arasında bir sayı tuttum.")
print("Toplam 10 tahmin hakkınız var.")

while sayac < tahmin_hakki:
    tahmin = int(input("Tahmininizi giriniz: "))
    sayac += 1

    if tahmin == tutulan_sayi:
        print("Tebrikler! Doğru tahmin ettiniz.")
        print("Toplam tahmin sayınız:", sayac)
        break

    elif tahmin > tutulan_sayi:
        print("Bilgisayarın tuttuğu sayı daha küçük bir sayıydı, lütfen daha küçük bir sayı giriniz.")
    
    else:  # tahmin < tutulan_sayi
        print("Bilgisayarın tuttuğu sayı daha büyük bir sayıydı, lütfen daha büyük bir sayı giriniz.")

    print("Kalan tahmin hakkınız:", tahmin_hakki - sayac)

else:
    print("Maalesef bilemediniz.")
    print("Tutulan sayı:", tutulan_sayi)
# Out:
# 1 ile 100 arasında bir sayı tuttum.
# Toplam 10 tahmin hakkınız var.
# Tahmininizi giriniz:  50
# Bilgisayarın tuttuğu sayı daha küçük bir sayıydı, lütfen daha küçük bir sayı giriniz.
# Kalan tahmin hakkınız: 9
# Tahmininizi giriniz:  25
# Bilgisayarın tuttuğu sayı daha küçük bir sayıydı, lütfen daha küçük bir sayı giriniz.
# Kalan tahmin hakkınız: 8
# Tahmininizi giriniz:  12
# Bilgisayarın tuttuğu sayı daha küçük bir sayıydı, lütfen daha küçük bir sayı giriniz.
# Kalan tahmin hakkınız: 7
# Tahmininizi giriniz:  6
# Bilgisayarın tuttuğu sayı daha küçük bir sayıydı, lütfen daha küçük bir sayı giriniz.
# Kalan tahmin hakkınız: 6
# Tahmininizi giriniz:  3
# Bilgisayarın tuttuğu sayı daha büyük bir sayıydı, lütfen daha büyük bir sayı giriniz.
# Kalan tahmin hakkınız: 5
# Tahmininizi giriniz:  4
# Bilgisayarın tuttuğu sayı daha büyük bir sayıydı, lütfen daha büyük bir sayı giriniz.
# Kalan tahmin hakkınız: 4
# Tahmininizi giriniz:  5
# Tebrikler! Doğru tahmin ettiniz.
# ...

# %% [markdown]
# #### 🔎 Kodun Mantığı
#
# 🎯 random.randint(1, 100) → Bilgisayar 1–100 arası sayı tutar.
#
# 🎯 while sayac < tahmin_hakki → 10 tahmin hakkı kontrol edilir.
#
# 🎯 if tahmin == tutulan_sayi → Doğru tahmin edilirse döngü break ile biter.
#
# 🎯 elif tahmin > tutulan_sayi → Daha küçük sayı girilmesi gerektiği söylenir.
#
# 🎯 else → Daha büyük sayı girilmesi gerektiği söylenir.
#
# 🎯 Eğer 10 tahminde bilinmezse while-else çalışır.

# %% [markdown]
# #### 🧠 Sen de yap
#
# ✅ 1’den 50’ye kadar çift sayıları yazdırın.
#
# ✅ Girilen sayı pozitif olduğu sürece toplamaya devam eden program yazın.
#
# ✅ 5 hak tanıyan bir şifre sistemi yazın.
